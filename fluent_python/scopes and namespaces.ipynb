# %%
# Scratch code based on the study of
# https://realpython.com/python-scope-legb-rule/

# %%
import sys

# %%
sys.__dict__.keys()
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', 'addaudithook', 'audit', 'breakpointhook', 'callstats', '_clear_type_cache', '_current_frames', 'displayhook', 'exc_info', 'excepthook', 'exit', 'getdefaultencoding', 'getallocatedblocks', 'getfilesystemencoding', 'getfilesystemencodeerrors', 'getrefcount', 'getrecursionlimit', 'getsizeof', '_getframe', 'getwindowsversion', '_enablelegacywindowsfsencoding', 'intern', 'is_finalizing', 'setcheckinterval', 'getcheckinterval', 'setswitchinterval', 'getswitchinterval', 'setprofile', 'getprofile', 'setrecursionlimit', 'settrace', 'gettrace', 'call_tracing', '_debugmallocstats', 'set_coroutine_origin_tracking_depth', 'get_coroutine_origin_tracking_depth', 'set_asyncgen_hooks', 'get_asyncgen_hooks', 'unraisablehook', 'modules', 'stderr', '__stderr__', '__displayhook__', '__excepthook__', '__breakpointhook__', '__unraisablehook__', 'version', 'hexversion', '_git', '_framework', 'api_version', 'copyright', 'platform', '
# ...

# %%
a = 5
b = 11

# %%
dir()
# Out:
# ['In',
#  'NamespaceMagics',
#  'Out',
#  '_',
#  '_1',
#  '_2',
#  '_3',
#  '_4',
#  '_5',
#  '__',
#  '__K',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__ipywidgets',
#  '__loader__',
#  '__name__',
#  '__np',
#  '__package__',
#  '__pd',
#  '__pyspark',
#  '__spec__',
#  '__tf',
#  '_check_imported',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_jupyterlab_variableinspector_Jupyter',
#  '_jupyterlab_variableinspector_default',
#  '_jupyterlab_variableinspector_deletevariable',
#  '_jupyterlab_variableinspector_dict_list',
#  '_jupyterlab_variableinspector_displaywidget',
#  '_jupyterlab_variableinspector_getcontentof',
#  '_jupyterlab_variableinspector_getmatrixcontent',
#  '_jupyterlab_variableinspector_getshapeof',
#  '_jupyterlab_variableinspector_getsizeof',
#  '_jupyterlab_variableinspector_is_matrix',
#  '_jupyterlab_variableinspector_is_widget',
#  '_jupyterlab_variableinspector_nms',
# ...

# %%
print(__dict__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-85ea60e2c81f> in <module>
# ----> 1 print(__dict__)
#
# NameError: name '__dict__' is not defined

# %%
print(__name__)
# Out:
# __main__

# %%
dir(__name__)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
dir(__name__.__dict__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-80aa40564a74> in <module>
# ----> 1 dir(__name__.__dict__)
#
# AttributeError: 'str' object has no attribute '__dict__'

# %%
c = getattr(__name__, '__dict__')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-2d0cdd891dd9> in <module>
# ----> 1 c = getattr(__name__, '__dict__')
#
# AttributeError: 'str' object has no attribute '__dict__'

# %%
c = getattr(__main__, '__dict__')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8844e76cd02e> in <module>
# ----> 1 c = getattr(__main__, '__dict__')
#
# NameError: name '__main__' is not defined

# %%
dir()
# Out:
# ['In',
#  'NamespaceMagics',
#  'Out',
#  '_',
#  '_1',
#  '_10',
#  '_11',
#  '_12',
#  '_2',
#  '_3',
#  '_4',
#  '_5',
#  '_6',
#  '_8',
#  '_9',
#  '__',
#  '__K',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__ipywidgets',
#  '__loader__',
#  '__name__',
#  '__np',
#  '__package__',
#  '__pd',
#  '__pyspark',
#  '__spec__',
#  '__tf',
#  '_check_imported',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_jupyterlab_variableinspector_Jupyter',
#  '_jupyterlab_variableinspector_default',
#  '_jupyterlab_variableinspector_deletevariable',
#  '_jupyterlab_variableinspector_dict_list',
#  '_jupyterlab_variableinspector_displaywidget',
#  '_jupyterlab_variableinspector_getcontentof',
#  '_jupyterlab_variableinspector_getmatrixcontent',
#  '_jupyterlab_variableinspector_getshapeof',
#  '_jupyterlab_variableinspector_getsizeof',
# ...

# %%
print(type(__name__), __name__)
# Out:
# <class 'str'> __main__

# %%
dir(__name__)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
dir(__name__.__dir__)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__text_signature__']

# %%
a = sys.modules['__main__'].__dict__

# %%
dir(a)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
print(a.items)
# Out:
# <built-in method items of dict object at 0x055DF6E0>

# %%
def cube(base):
    result = base ** 3
    print(f'The cube of {base} is: {result}')

cube(30)
# Out:
# The cube of 30 is: 27000

# %%
type(cube.__code__)
# Out:
# code

# %%
a = cube.__code__
b = dir(a)
# print(b)

for i in b:
    print(f'{i}:')
    c = getattr(a, i)
    print ("   ", c)
# Out:
# __class__:
#     <class 'code'>
# __delattr__:
#     <method-wrapper '__delattr__' of code object at 0x07048770>
# __dir__:
#     <built-in method __dir__ of code object at 0x07048770>
# __doc__:
#     code(argcount, posonlyargcount, kwonlyargcount, nlocals, stacksize,
#       flags, codestring, constants, names, varnames, filename, name,
#       firstlineno, lnotab[, freevars[, cellvars]])
#
# Create a code object.  Not for the faint of heart.
# __eq__:
#     <method-wrapper '__eq__' of code object at 0x07048770>
# __format__:
#     <built-in method __format__ of code object at 0x07048770>
# __ge__:
#     <method-wrapper '__ge__' of code object at 0x07048770>
# __getattribute__:
#     <method-wrapper '__getattribute__' of code object at 0x07048770>
# __gt__:
#     <method-wrapper '__gt__' of code object at 0x07048770>
# __hash__:
#     <method-wrapper '__hash__' of code object at 0x07048770>
# __init__:
#     <method-wrapper '__init__' of code object at 0x07048770>
# ...

# %%
def outer_func():
    # This block is the Local scope of outer_func()
    var = 100  # A nonlocal var
    # It's also the enclosing scope of inner_func()
    def inner_func():
        # This block is the Local scope of inner_func()
        print(f"Printing var from inner_func(): {var}")

    inner_func()
    print(f"Printing var from outer_func(): {var}")

outer_func()


inner_func()
# Out:
# Printing var from inner_func(): 100
# Printing var from outer_func(): 100
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-3dfa967da06c> in <module>
#      13
#      14
# ---> 15 inner_func()
#
# NameError: name 'inner_func' is not defined

# %%
def outer_func():
    var = 100
    def inner_func():
        print(f"Printing var from inner_func(): {var}")
        print(f"Printing another_var from inner_func(): {another_var}")

    another_var = 200  # This is defined after calling inner_func()
    inner_func()
    print(f"Printing var from outer_func(): {var}")

outer_func()
# Out:
# Printing var from inner_func(): 100
# Printing another_var from inner_func(): 200
# Printing var from outer_func(): 100

# %%
dir()
# Out:
# ['In',
#  'NamespaceMagics',
#  'Out',
#  '_',
#  '_1',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_16',
#  '_17',
#  '_18',
#  '_19',
#  '_2',
#  '_20',
#  '_21',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_26',
#  '_27',
#  '_28',
#  '_29',
#  '_3',
#  '_30',
#  '_31',
#  '_32',
#  '_33',
#  '_34',
#  '_35',
#  '_36',
#  '_37',
#  '_4',
#  '_5',
#  '_6',
#  '_8',
#  '_9',
#  '__',
#  '__K',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__ipywidgets',
#  '__loader__',
#  '__name__',
#  '__np',
#  '__package__',
#  '__pd',
#  '__pyspark',
#  '__spec__',
#  '__tf',
#  '_check_imported',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
# ...

# %%
dir(__builtin__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# Scratch code based on the study of\n# https://realpython.com/python-scope-legb-rule/',
#   'import sys',
#   'sys.__dict__.keys()',
#   'a = 5\nb = 11',
#   'dir()',
#   'print(__dict__)',
#   'print(__name__)',
#   'dir(__name__)',
#   'dir(__name__.__dict__)',
#   "c = getattr(__name__, '__dict__')",
#   "c = getattr(__main__, '__dict__')",
#   'dir()',
#   'print(type(__name__), __name__)',
#   'dir(__name__)',
#   'dir(__name__.__dir__)',
#   "a = sys.modules['__main__'].__dict__",
#   'dir(a)',
#   'dir(a.items)',
#   'dir(a.values)',
#   'print(a.items)',
#   "def cube(base):\n    result = base ** 3\n    print(f'The cube of {base} is: {result}')\n\ncube(30)",
#   'cube.__code__',
# ...

# %%
a = vars()

# %%
print(type(a))
# Out:
# <class 'dict'>

# %%
print(a)
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'a = vars()', 'print(type(a))', 'print(a)'], '_oh': {1: '[]', 2: '[{"varName": "a", "varType": "dict", "varSize": "1208", "varShape": "46 keys", "varContent": "{\'__name__\': \'__main__\', \'__doc__\': \'Automatically created module for IPython interactive environment\', \'__package__\': None, \'__loader__\': None, \'__sp ...", "isMatrix": false, "isWidget": null}]', 3: '[{"varName": "a", "varType": "dict", "varSize": "1208", "varShape": "48 keys", "varContent": "{\'__name__\': \'__main__\', \'__doc__\': \'Automatically created module for IPython interactive environment\', \'__package__\': None, \'__loader__\': None, \'__sp ...", "isMatrix": false, "isWidget": null}]'}, '_dh': ['D:\\Google Drive\\My Documents\\code\\py
# ...

# %%
class MyClass:
    def __init__(self, var):
        self.var = var

obj = MyClass(100)

a=vars(obj)  # With a user-defined object

b=vars(MyClass)  # With a class

# %%
print(a)
# Out:
# {'var': 100}

# %%
print(b)
# Out:
# {'__module__': '__main__', '__init__': <function MyClass.__init__ at 0x05F1DA48>, '__dict__': <attribute '__dict__' of 'MyClass' objects>, '__weakref__': <attribute '__weakref__' of 'MyClass' objects>, '__doc__': None}

# %%
print(b['__dict__'])
# Out:
# <attribute '__dict__' of 'MyClass' objects>

# %%
for k,v in b['__dict__']:
    print(f'{k}: {v}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d3b40b4e6dc0> in <module>
# ----> 1 for k,v in b['__dict__']:
#       2     print(f'{k}: {v}')
#
# TypeError: 'getset_descriptor' object is not iterable

# %%
type(b['__dict__'])
# Out:
# getset_descriptor

# %%
help(getset_descriptor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a18d09864101> in <module>
# ----> 1 help(getset_descriptor)
#
# NameError: name 'getset_descriptor' is not defined

# %%
def func():
    var = 100
    print(dir())
    print(vars())
    another = 200  # Is defined after calling dir()

func()
# Out:
# ['var']
# {'var': 100}

# %%
vars()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'a = vars()',
#   'print(type(a))',
#   'print(a)',
#   'class MyClass:\n    def __init__(self, var):\n        self.var = var\n\nobj = MyClass(100)\n\na=vars(obj)  # With a user-defined object\n\nb=vars(MyClass)  # With a class',
#   'print(a)',
#   'print(b)',
#   "print(b['__dict__'])",
#   "for k,v in b['__dict__']:\n    print(f'{k}: {v}')",
#   "type(b['__dict__'])",
#   'help(getset_descriptor)',
#   'def func():\n    var = 100\n    print(dir())\n    print(vars())\n    another = 200  # Is defined after calling dir()\n\nfunc()',
#   'vars()'],
#  '_oh': {1: '[]',
# ...

# %%
vars().keys() is dir()
# Out:
# False

# %%
vars().keys() == dir()
# Out:
# False

# %%
vars().keys()
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', 'json', 'sys', 'NamespaceMagics', '_jupyterlab_variableinspector_nms', '_jupyterlab_variableinspector_Jupyter', '__np', '__pd', '__pyspark', '__tf', '__K', '__ipywidgets', '_check_imported', '_jupyterlab_variableinspector_getsizeof', '_jupyterlab_variableinspector_getshapeof', '_jupyterlab_variableinspector_getcontentof', '_jupyterlab_variableinspector_is_matrix', '_jupyterlab_variableinspector_is_widget', '_jupyterlab_variableinspector_dict_list', '_jupyterlab_variableinspector_getmatrixcontent', '_jupyterlab_variableinspector_displaywidget', '_jupyterlab_variableinspector_default', '_jupyterlab_variableinspector_deletevariable', '_1', '_i', '_ii', '_iii', '_i1', 'a', '_2', '_i2', '_3', '_i3', '_4', '_i4', 'MyClass', 'obj', 'b', '_5', '_i5', '_6', '_i6', '_7', '_i7', '_8', '_i8', '_i9', '_9', '_10
# ...

# %%
dir()
# Out:
# ['In',
#  'MyClass',
#  'NamespaceMagics',
#  'Out',
#  '_',
#  '_1',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_16',
#  '_2',
#  '_3',
#  '_4',
#  '_5',
#  '_6',
#  '_7',
#  '_8',
#  '_9',
#  '__',
#  '__K',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__ipywidgets',
#  '__loader__',
#  '__name__',
#  '__np',
#  '__package__',
#  '__pd',
#  '__pyspark',
#  '__spec__',
#  '__tf',
#  '_check_imported',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_jupyterlab_variableinspector_Jupyter',
#  '_jupyterlab_variableinspector_default',
#  '_jupyterlab_variableinspector_deletevariable',
#  '_jupyterlab_variableinspector_dict_list',
#  '_jupyterlab_variableinspector_displaywidget',
#  '_jupyterlab_variableinspector_getcontentof',
# ...

# %%
a = list(vars().keys())

# %%
a = list(vars().keys())
b = list(dir())

# %%
a.sort()
b.sort()

# %%
print(a)
print(b)
# Out:
# ['In', 'MyClass', 'NamespaceMagics', 'Out', '_', '_1', '_10', '_11', '_12', '_13', '_14', '_15', '_16', '_17', '_18', '_19', '_2', '_20', '_21', '_22', '_24', '_25', '_26', '_27', '_3', '_4', '_5', '_6', '_7', '_8', '_9', '__', '__K', '___', '__builtin__', '__builtins__', '__doc__', '__ipywidgets', '__loader__', '__name__', '__np', '__package__', '__pd', '__pyspark', '__spec__', '__tf', '_check_imported', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i26', '_i27', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_jupyterlab_variableinspector_Jupyter', '_jupyterlab_variableinspector_default', '_jupyterlab_variableinspector_deletevariable', '_jupyterlab_variableinspector_dict_list', '_jupyterlab_variableinspector_displaywidget', '_jupyterlab_variableinspector_getcontentof', '_jupyterlab_variableinspector_getmatrixcontent', '_jupyterlab_variableinspector_
# ...

# %%
for i, j in zip(a, b):
    print(i, j)
# Out:
# In In
# MyClass MyClass
# NamespaceMagics NamespaceMagics
# Out Out
# _ _
# _1 _1
# _10 _10
# _11 _11
# _12 _12
# _13 _13
# _14 _14
# _15 _15
# _16 _16
# _17 _17
# _18 _18
# _19 _19
# _2 _2
# _20 _20
# _21 _21
# _22 _22
# _24 _24
# _25 _25
# _26 _26
# _27 _27
# _3 _28
# _4 _3
# _5 _4
# _6 _5
# _7 _6
# _8 _7
# _9 _8
# __ _9
# __K __
# ___ __K
# __builtin__ ___
# __builtins__ __builtin__
# __doc__ __builtins__
# __ipywidgets __doc__
# __loader__ __ipywidgets
# __name__ __loader__
# __np __name__
# __package__ __np
# __pd __package__
# __pyspark __pd
# __spec__ __pyspark
# __tf __spec__
# _check_imported __tf
# _dh _check_imported
# _i _dh
# _i1 _i
# _i10 _i1
# _i11 _i10
# _i12 _i11
# _i13 _i12
# _i14 _i13
# _i15 _i14
# _i16 _i15
# _i17 _i16
# _i18 _i17
# _i19 _i18
# _i2 _i19
# _i20 _i2
# _i21 _i20
# _i22 _i21
# _i23 _i22
# _i24 _i23
# _i25 _i24
# _i26 _i25
# _i27 _i26
# _i3 _i27
# _i4 _i28
# _i5 _i3
# _i6 _i4
# _i7 _i5
# _i8 _i6
# _i9 _i7
# _ih _i8
# _ii _i9
# _iii _ih
# ...

# %%
sorted(list(vars().keys())) is sorted(list(dir()))
# Out:
# False

# %%
diff = set(set(sorted(list(vars().keys()))) - set(sorted(list(dir()))))

# %%
print(diff)
# Out:
# set()

# %%
a = list(vars().keys())
b = list(dir())
a.sort()
b.sort()
c = set(a)
d = set(b)
e = set(a) - set(b)
print(e)
# Out:
# set()

# %%
print(a)
# Out:
# ['In', 'MyClass', 'NamespaceMagics', 'Out', '_', '_1', '_10', '_11', '_12', '_13', '_14', '_15', '_16', '_17', '_18', '_19', '_2', '_20', '_21', '_22', '_24', '_25', '_26', '_27', '_28', '_29', '_3', '_30', '_31', '_32', '_33', '_34', '_35', '_36', '_4', '_5', '_6', '_7', '_8', '_9', '__', '__K', '___', '__builtin__', '__builtins__', '__doc__', '__ipywidgets', '__loader__', '__name__', '__np', '__package__', '__pd', '__pyspark', '__spec__', '__tf', '_check_imported', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i26', '_i27', '_i28', '_i29', '_i3', '_i30', '_i31', '_i32', '_i33', '_i34', '_i35', '_i36', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_jupyterlab_variableinspector_Jupyter', '_jupyterlab_variableinspector_default', '_jupyterlab_variableinspector_deletevariable', '_jupyterlab_variableinspector_dict_list', '_jupyterlab_variableinspector_displayw
# ...

# %%
print(b)
# Out:
# ['In', 'MyClass', 'NamespaceMagics', 'Out', '_', '_1', '_10', '_11', '_12', '_13', '_14', '_15', '_16', '_17', '_18', '_19', '_2', '_20', '_21', '_22', '_24', '_25', '_26', '_27', '_28', '_29', '_3', '_30', '_31', '_32', '_33', '_34', '_35', '_36', '_4', '_5', '_6', '_7', '_8', '_9', '__', '__K', '___', '__builtin__', '__builtins__', '__doc__', '__ipywidgets', '__loader__', '__name__', '__np', '__package__', '__pd', '__pyspark', '__spec__', '__tf', '_check_imported', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i26', '_i27', '_i28', '_i29', '_i3', '_i30', '_i31', '_i32', '_i33', '_i34', '_i35', '_i36', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_jupyterlab_variableinspector_Jupyter', '_jupyterlab_variableinspector_default', '_jupyterlab_variableinspector_deletevariable', '_jupyterlab_variableinspector_dict_list', '_jupyterlab_variableinspector_displayw
# ...

# %%
c is d
# Out:
# False

# %%
c == d
# Out:
# True

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'a = vars()',
#   'print(type(a))',
#   'print(a)',
#   'class MyClass:\n    def __init__(self, var):\n        self.var = var\n\nobj = MyClass(100)\n\na=vars(obj)  # With a user-defined object\n\nb=vars(MyClass)  # With a class',
#   'print(a)',
#   'print(b)',
#   "print(b['__dict__'])",
#   "for k,v in b['__dict__']:\n    print(f'{k}: {v}')",
#   "type(b['__dict__'])",
#   'help(getset_descriptor)',
#   'def func():\n    var = 100\n    print(dir())\n    print(vars())\n    another = 200  # Is defined after calling dir()\n\nfunc()',
#   'vars()',
#   'vars().keys() is dir() ',
#   'vars().keys() == dir() ',
#   'vars().keys()',
#   'dir() ',
#   'list(vars().keys())',
#   'list(dir())',
# ...

# %%
a = vars()

# %%
print(a)
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'a = vars()', 'print(type(a))', 'print(a)', 'class MyClass:\n    def __init__(self, var):\n        self.var = var\n\nobj = MyClass(100)\n\na=vars(obj)  # With a user-defined object\n\nb=vars(MyClass)  # With a class', 'print(a)', 'print(b)', "print(b['__dict__'])", "for k,v in b['__dict__']:\n    print(f'{k}: {v}')", "type(b['__dict__'])", 'help(getset_descriptor)', 'def func():\n    var = 100\n    print(dir())\n    print(vars())\n    another = 200  # Is defined after calling dir()\n\nfunc()', 'vars()', 'vars().keys() is dir() ', 'vars().keys() == dir() ', 'vars().keys()', 'dir() ', 'list(vars().keys())', 'list(dir())', 'list(vars().keys()).sort()', 'list(dir()).sort()', 'print(list(vars().keys()).sort())\nprint(list(d
# ...
