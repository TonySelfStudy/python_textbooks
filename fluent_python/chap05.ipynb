# %%
import tony_util.misc

# %%
a = dir()
print(a)
# Out:
# ['In', 'NamespaceMagics', 'Out', '_', '__', '__K', '___', '__builtin__', '__builtins__', '__doc__', '__ipywidgets', '__loader__', '__name__', '__np', '__package__', '__pd', '__pyspark', '__spec__', '__tf', '_check_imported', '_dh', '_i', '_i1', '_i2', '_ih', '_ii', '_iii', '_jupyterlab_variableinspector_Jupyter', '_jupyterlab_variableinspector_default', '_jupyterlab_variableinspector_deletevariable', '_jupyterlab_variableinspector_dict_list', '_jupyterlab_variableinspector_displaywidget', '_jupyterlab_variableinspector_getcontentof', '_jupyterlab_variableinspector_getmatrixcontent', '_jupyterlab_variableinspector_getshapeof', '_jupyterlab_variableinspector_getsizeof', '_jupyterlab_variableinspector_is_matrix', '_jupyterlab_variableinspector_is_widget', '_jupyterlab_variableinspector_nms', '_oh', 'exit', 'get_ipython', 'json', 'quit', 'sys', 'tony_util']

# %%
[i for i in dir() if i.startswith("__")]
# Out:
# ['__',
#  '__K',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__ipywidgets',
#  '__loader__',
#  '__name__',
#  '__np',
#  '__package__',
#  '__pd',
#  '__pyspark',
#  '__spec__',
#  '__tf']

# %%
def func1(): pass
fun_dict = set(dir(func1))
obj_dict = set(dir(object))
fun_unique = set(fun_dict - obj_dict)
print(fun_unique)
# Out:
# {'__code__', '__get__', '__qualname__', '__defaults__', '__name__', '__call__', '__kwdefaults__', '__closure__', '__globals__', '__dict__', '__annotations__', '__module__'}

# %%
print(func1.__closure__)
# Out:
# None

# %%
dir(abs)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__text_signature__']

# %%
print(abs)
# Out:
# <built-in function abs>

# %%
print(dict)
# Out:
# <class 'dict'>

# %%
print(dict.get)
# Out:
# <method 'get' of 'dict' objects>

# %%
print(dir(dict))
# Out:
# ['__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
def clip(text=None, max_length=80):
    """
    Return text clipped at the last space before or after max_len
    """
    end = None
    if len(text) > max_length:
        space_before = text.rfind(' ', 0, max_length)
        if space_before >= 0:
            end = space_before
        else:
            space_after = text.rfind(' ', max_length)
            if space_after >= 0:
                end = space_after

        if end is None:
            end = len(text)

        return text[:end].rstrip()

# %%
fun_dict = set(dir(clip))
obj_dict = set(dir(object))
fun_unique = set(fun_dict - obj_dict)
attrs =fun_unique
print(attrs)
# Out:
# {'__code__', '__get__', '__qualname__', '__defaults__', '__name__', '__call__', '__kwdefaults__', '__closure__', '__globals__', '__dict__', '__annotations__', '__module__'}

# %%
from tony_util.misc import get_max_char
max_char = 500

# %%
for i in attrs:
    print('*'*40, '\n', "\t", i, '\n', '*'*40, )
    b = get_max_char(str(getattr(clip, i)))
    print(b)
# Out:
# ****************************************
#  	 __code__
#  ****************************************
# <code object clip at 0x05E16AB0, file "<ipython-input-11-5ef449404cb2>", line 1>
# ****************************************
#  	 __get__
#  ****************************************
# <method-wrapper '__get__' of function object at 0x05E3A1D8>
# ****************************************
#  	 __qualname__
#  ****************************************
# clip
# ****************************************
#  	 __defaults__
#  ****************************************
# (None, 80)
# ****************************************
#  	 __name__
#  ****************************************
# clip
# ****************************************
#  	 __call__
#  ****************************************
# <method-wrapper '__call__' of function object at 0x05E3A1D8>
# ****************************************
#  	 __kwdefaults__
#  ****************************************
# None
# ...

# %%
attrs =clip.__code__
print(dir(attrs), '\n')
attrs_no_dunders = [i for i in dir(attrs) if not i.startswith("__")]
print(attrs_no_dunders)
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'co_argcount', 'co_cellvars', 'co_code', 'co_consts', 'co_filename', 'co_firstlineno', 'co_flags', 'co_freevars', 'co_kwonlyargcount', 'co_lnotab', 'co_name', 'co_names', 'co_nlocals', 'co_posonlyargcount', 'co_stacksize', 'co_varnames', 'replace']
#
# ['co_argcount', 'co_cellvars', 'co_code', 'co_consts', 'co_filename', 'co_firstlineno', 'co_flags', 'co_freevars', 'co_kwonlyargcount', 'co_lnotab', 'co_name', 'co_names', 'co_nlocals', 'co_posonlyargcount', 'co_stacksize', 'co_varnames', 'replace']

# %%
for i in attrs_no_dunders:
    print('*'*40, '\n', "\t", i, '\n', '*'*40, )
    b = getattr(clip.__code__, i)
    print(b)
# Out:
# ****************************************
#  	 co_argcount
#  ****************************************
# 2
# ****************************************
#  	 co_cellvars
#  ****************************************
# ()
# ****************************************
#  	 co_code
#  ****************************************
# b'd\x01}\x02t\x00|\x00\x83\x01|\x01k\x04rd|\x00\xa0\x01d\x02d\x03|\x01\xa1\x03}\x03|\x03d\x03k\x05r,|\x03}\x02n\x18|\x00\xa0\x01d\x02|\x01\xa1\x02}\x04|\x04d\x03k\x05rD|\x04}\x02|\x02d\x01k\x08rTt\x00|\x00\x83\x01}\x02|\x00d\x01|\x02\x85\x02\x19\x00\xa0\x02\xa1\x00S\x00d\x01S\x00'
# ****************************************
#  	 co_consts
#  ****************************************
# ('\n    Return text clipped at the last space before or after max_len\n    ', None, ' ', 0)
# ****************************************
#  	 co_filename
#  ****************************************
# <ipython-input-11-5ef449404cb2>
# ****************************************
#  	 co_firstlineno
# ...

# %%
import inspect

# %%
dir(inspect)
# Out:
# ['ArgInfo',
#  'ArgSpec',
#  'Arguments',
#  'Attribute',
#  'BlockFinder',
#  'BoundArguments',
#  'CORO_CLOSED',
#  'CORO_CREATED',
#  'CORO_RUNNING',
#  'CORO_SUSPENDED',
#  'CO_ASYNC_GENERATOR',
#  'CO_COROUTINE',
#  'CO_GENERATOR',
#  'CO_ITERABLE_COROUTINE',
#  'CO_NESTED',
#  'CO_NEWLOCALS',
#  'CO_NOFREE',
#  'CO_OPTIMIZED',
#  'CO_VARARGS',
#  'CO_VARKEYWORDS',
#  'ClosureVars',
#  'EndOfBlock',
#  'FrameInfo',
#  'FullArgSpec',
#  'GEN_CLOSED',
#  'GEN_CREATED',
#  'GEN_RUNNING',
#  'GEN_SUSPENDED',
#  'OrderedDict',
#  'Parameter',
#  'Signature',
#  'TPFLAGS_IS_ABSTRACT',
#  'Traceback',
#  '_ClassMethodWrapper',
#  '_KEYWORD_ONLY',
#  '_MethodWrapper',
#  '_NonUserDefinedCallables',
#  '_PARAM_NAME_MAPPING',
#  '_POSITIONAL_ONLY',
#  '_POSITIONAL_OR_KEYWORD',
#  '_ParameterKind',
#  '_VAR_KEYWORD',
#  '_VAR_POSITIONAL',
#  '_WrapperDescriptor',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
# ...

# %%
a = dir(inspect)
max_char = 500
for i in a:
    if not i.startswith("_"):
        print(f"\n{'*'*10}{i}{'*'*10}")
        f = getattr(inspect, i)
        try:
            a = str(f(clip))
            print(get_max_char(a))
        except:
            b = str(f"Can't call {f}(clip)")
            print(get_max_char(b))
                
#         print(dir(i))
#         print(i.__doc__)
# Out:
# **********ArgInfo**********
# Can't call <class 'inspect.ArgInfo'>(clip)
#
# **********ArgSpec**********
# Can't call <class 'inspect.ArgSpec'>(clip)
#
# **********Arguments**********
# Can't call <class 'inspect.Arguments'>(clip)
#
# **********Attribute**********
# Can't call <class 'inspect.Attribute'>(clip)
#
# **********BlockFinder**********
# Can't call <class 'inspect.BlockFinder'>(clip)
#
# **********BoundArguments**********
# Can't call <class 'inspect.BoundArguments'>(clip)
#
# **********CORO_CLOSED**********
# Can't call CORO_CLOSED(clip)
#
# **********CORO_CREATED**********
# Can't call CORO_CREATED(clip)
#
# **********CORO_RUNNING**********
# Can't call CORO_RUNNING(clip)
#
# **********CORO_SUSPENDED**********
# Can't call CORO_SUSPENDED(clip)
#
# **********CO_ASYNC_GENERATOR**********
# Can't call 512(clip)
#
# **********CO_COROUTINE**********
# Can't call 128(clip)
#
# **********CO_GENERATOR**********
# Can't call 32(clip)
#
# **********CO_ITERABLE_COROUTINE**********
# ...

# %%
sig = inspect.signature
clip_sig = sig(clip)
print(clip_sig)
# Out:
# (text=None, max_length=80)

# %%
dir()
# Out:
# ['In',
#  'NamespaceMagics',
#  'Out',
#  '_',
#  '_18',
#  '_3',
#  '_6',
#  '__',
#  '__K',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__ipywidgets',
#  '__loader__',
#  '__name__',
#  '__np',
#  '__package__',
#  '__pd',
#  '__pyspark',
#  '__spec__',
#  '__tf',
#  '_check_imported',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_jupyterlab_variableinspector_Jupyter',
#  '_jupyterlab_variableinspector_default',
#  '_jupyterlab_variableinspector_deletevariable',
#  '_jupyterlab_variableinspector_dict_list',
#  '_jupyterlab_variableinspector_displaywidget',
#  '_jupyterlab_variableinspector_getcontentof',
#  '_jupyterlab_variableinspector_getmatrixcontent',
#  '_jupyterlab_variableinspector_getshapeof',
# ...

# %%
dir()
# Out:
# ['In',
#  'NamespaceMagics',
#  'Out',
#  '_',
#  '_18',
#  '_21',
#  '_3',
#  '_6',
#  '__',
#  '__K',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__ipywidgets',
#  '__loader__',
#  '__name__',
#  '__np',
#  '__package__',
#  '__pd',
#  '__pyspark',
#  '__spec__',
#  '__tf',
#  '_check_imported',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_jupyterlab_variableinspector_Jupyter',
#  '_jupyterlab_variableinspector_default',
#  '_jupyterlab_variableinspector_deletevariable',
#  '_jupyterlab_variableinspector_dict_list',
#  '_jupyterlab_variableinspector_displaywidget',
#  '_jupyterlab_variableinspector_getcontentof',
#  '_jupyterlab_variableinspector_getmatrixcontent',
#  '_jupyterlab_variableinspector_getshapeof',
# ...

# %%
dir(__name__)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...
